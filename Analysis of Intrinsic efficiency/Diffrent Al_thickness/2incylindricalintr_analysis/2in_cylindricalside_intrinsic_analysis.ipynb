# %% [markdown]
# ## Intrinsic efficiency for cylindrical side of 2in for Al=0.05cm

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math


data1=pd.read_csv("five.csv")
data11=data1["Calculation"]*100
data12=data1["Simulation"]*100



average=0
sigma=0
for number in data12:
    average+=number/len(data12)
for number in data12:
    sigma+=((number-average)*(number-average)/len(data12))
sigma=math.sqrt(sigma)
e1=sigma/math.sqrt(len(data12))

x_positions=[]

Positions=np.arange(-2, 2.2, 0.2)


for i in Positions:
    x_positions.append(i)
    


plt.scatter(x_positions, data11,s=30, color="none", edgecolor="blue",marker='d', label="Calculation(Al=0.05 cm)")
plt.scatter(x_positions, data12,s=30, color="none", edgecolor="cyan",marker='^', label="Calculation(Al=0.05 cm)")
plt.legend()
plt.legend(handlelength=0.8, handleheight=0.8)
plt.rc('legend',fontsize=7)
plt.savefig("Circular.pdf", bbox_inches='tight')
plt.show()


data1
# Out:
#     Unnamed: 0  Calculation  Simulation
# 0            0     0.096262    0.096562
# 1            1     0.089514    0.089314
# 2            2     0.083953    0.083125
# 3            3     0.079183    0.079583
# 4            4     0.075379    0.075079
# 5            5     0.072958    0.072558
# 6            6     0.072320    0.072620
# 7            7     0.073709    0.073101
# 8            8     0.076968    0.076568
# 9            9     0.080923    0.080623
# 10          10     0.082952    0.082125
# 11          11     0.080923    0.080623
# 12          12     0.076968    0.076568
# 13          13     0.073709    0.073409
# 14          14     0.072320    0.072620
# 15          15     0.072958    0.072558
# 16          16     0.075379    0.075679
# 17          17     0.079183    0.079483
# 18          18     0.083953    0.083553
# 19          19     0.089514    0.089114
# 20          20     0.096262    0.096562

# %% [markdown]
# ## Intrinsic efficiency for cylindrical side of 2in for Al=0.1cm

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math



x_positions=[]


Positions=np.arange(-2,2.2, 0.2)


for i in Positions:
    x_positions.append(i)



final_data=pd.read_csv("ten.csv")


my_data=final_data["Calculation"]*100
simulation_data=final_data["Simulation"]*100


average=0
sigma=0
for number in simulation_data:
    average+=number/len(simulation_data)
for number in simulation_data:
    sigma+=((number-average)*(number-average)/len(simulation_data))
sigma=math.sqrt(sigma)
e2=sigma/math.sqrt(len(simulation_data))




plt.scatter(x_positions, data11,s=30, color="none", edgecolor="blue",marker="d", label="Calculation(Al=0.05 cm)")
plt.scatter(x_positions,data12, color='none', edgecolor='cyan', marker='^',label="Simulation(Al=0.05 cm)")
plt.scatter(x_positions, my_data,s=30,color="none", edgecolor="green", label="Calculation(Al=0.1 cm)")
plt.scatter(x_positions, simulation_data,s=30,color="none", edgecolor="red", marker='s',label="Simulation(Al=0.1 cm)")
plt.errorbar(x_positions,data12, yerr=e1,color="black", capsize=3,ls="none", label='Simulation uncertanity(Al=0.05 cm)')
plt.errorbar(x_positions,simulation_data, yerr=e2,color="grey", capsize=3,ls="none", label='Simulation uncertanity(Al=0.1 cm)')
plt.xlabel("Axial position y(cm)")
plt.ylabel("Intrinsic detection efficiency (%)")
plt.legend()
plt.rc('legend',fontsize=8)
plt.legend(handlelength=0.5, handleheight=0.1)
leg = plt.legend(loc ="upper right")
plt.ylim(6.5, 13)
plt.xticks(np.arange(-2,2.2,0.4), fontsize=7)
plt.savefig("Cylindrical.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Intrinsic efficiency for cylindrical side of 2in for Al=0.05cm

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math



x_positions=[]


Positions=np.arange(-3.6, 3.8, 0.2)


for i in Positions:
    x_positions.append(i)



data1=pd.read_csv("five.csv")
data3=data1["Calculation"]*math.exp(-0.15*0.7614)/math.exp(-0.05*0.7614)

with open("fifteen.csv", "w") as out_file:
     for number in data3:
        outstring=str(number)
        outstring+='\n'
        out_file.write(outstring)
        
data=pd.read_csv("fifteen.csv",names=['Calculation'])
data.to_csv("fifteennew.csv")

final_data=pd.read_csv("fifteennew.csv")
my_data=final_data["Calculation"]

print("***************length of x**************************")
print(len(x_positions))

print("***************length of y**************************")
print(len(my_data))

plt.scatter(x_positions, my_data,s=30,color="none", edgecolor="blue", label="Calculation(Al=0.15)")
# Out:
# ***************length of x**************************
# 37
# ***************length of y**************************
# 21
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a2402ba7efc2> in <module>
#      38 print(len(my_data))
#      39
# ---> 40 plt.scatter(x_positions, my_data,s=30,color="none", edgecolor="blue", label="Calculation(Al=0.15)")
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# ...
